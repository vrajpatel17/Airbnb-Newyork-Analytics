# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('AB_NYC_2019.csv')

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# ## Neighbourhood group

# %%
n = df['neighbourhood_group'].value_counts()
print(n)
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
sns.countplot(df['neighbourhood_group'], palette="plasma")
fig = plt.gcf()
fig.set_size_inches(10,5)
plt.title('Neighbourhood Group')
# Out:
# Text(0.5, 1.0, 'Neighbourhood Group')

# %% [markdown]
# ## Room types

# %%
df['room_type'].value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
sns.countplot(df['room_type'], palette = 'plasma')
fig = plt.gcf()
fig.set_size_inches(10,5)
plt.title('Neighbourhood Group')
# Out:
# Text(0.5, 1.0, 'Neighbourhood Group')

# %%
## Type of rooms in Manhattan
man_r = df.loc[df['neighbourhood_group'] == 'Manhattan']
print(man_r.room_type.value_counts())
# Out:
# Entire home/apt    13199
# Private room        7982
# Shared room          480
# Name: room_type, dtype: int64

# %%
br_r = df.loc[df['neighbourhood_group'] == 'Brooklyn']
print(br_r.room_type.value_counts())
# Out:
# Private room       10132
# Entire home/apt     9559
# Shared room          413
# Name: room_type, dtype: int64

# %%
print(df.loc[df['neighbourhood_group'] == 'Queens'].room_type.value_counts())
# Out:
# Private room       3372
# Entire home/apt    2096
# Shared room         198
# Name: room_type, dtype: int64

# %%
print(df.loc[df['neighbourhood_group'] == 'Bronx'].room_type.value_counts())
# Out:
# Private room       652
# Entire home/apt    379
# Shared room         60
# Name: room_type, dtype: int64

# %%
print(df.loc[df['neighbourhood_group'] == 'Staten Island'].room_type.value_counts())
# Out:
# Private room       188
# Entire home/apt    176
# Shared room          9
# Name: room_type, dtype: int64

# %% [markdown]
# ## Price analysis

# %%
df['price'].mean()
# Out:
# 152.7206871868289

# %%
sub_1=df.loc[df['neighbourhood_group'] == 'Brooklyn']
price_sub1=sub_1[['price']]

print(price_sub1.mean())
print(price_sub1.max())
print(price_sub1.min())
# Out:
# price    124.383207
# dtype: float64
# price    10000
# dtype: int64
# price    0
# dtype: int64

# %%
df['price'] = df['price'].replace(0,10)

sub_1=df.loc[df['neighbourhood_group'] == 'Brooklyn']   ##brooklyn
price_sub1=sub_1[['price']]

print(price_sub1.mean())
print(price_sub1.max())
print(price_sub1.min())
# Out:
# price    124.387684
# dtype: float64
# price    10000
# dtype: int64
# price    10
# dtype: int64

# %%
sub_2=df.loc[df['neighbourhood_group'] == 'Manhattan']   ##Manhattan
price_sub2=sub_2[['price']]

print(price_sub2.mean())
print(price_sub2.max())
print(price_sub2.min())
# Out:
# price    196.876275
# dtype: float64
# price    10000
# dtype: int64
# price    10
# dtype: int64

# %%
sub_3=df.loc[df['neighbourhood_group'] == 'Queens']   ##Queens
price_sub3=sub_3[['price']]

print(price_sub3.mean())
print(price_sub3.max())
print(price_sub3.min())
# Out:
# price    99.517649
# dtype: float64
# price    10000
# dtype: int64
# price    10
# dtype: int64

# %%
sub_4=df.loc[df['neighbourhood_group'] == 'Bronx']   ##Bronx
price_sub4=sub_4[['price']]

print(price_sub4.mean())
print(price_sub4.max())
print(price_sub4.min())
# Out:
# price    87.505958
# dtype: float64
# price    2500
# dtype: int64
# price    10
# dtype: int64

# %%
sub_5=df.loc[df['neighbourhood_group'] == 'Staten Island']   ##Staten Island
price_sub5=sub_5[['price']]

print(price_sub5.mean())
print(price_sub5.max())
print(price_sub5.min())
# Out:
# price    114.812332
# dtype: float64
# price    5000
# dtype: int64
# price    13
# dtype: int64

# %% [markdown]
# ## Neighbourhood

# %%
df['neighbourhood'].nunique()
# Out:
# 221

# %%
df['neighbourhood'].value_counts().head(10)
# Out:
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1564
# Midtown               1545
# Name: neighbourhood, dtype: int64

# %%
man_h = df.loc[df['neighbourhood_group'] == 'Manhattan']
print(man_h.neighbourhood.value_counts())

sns.countplot(y = man_h['neighbourhood'], palette = 'plasma')
fig = plt.gcf()
fig.set_size_inches(10,8)
plt.title('Neighbourhood')

print(man_h.neighbourhood.nunique())
# Out:
# Harlem                 2658
# Upper West Side        1971
# Hell's Kitchen         1958
# East Village           1853
# Upper East Side        1798
# Midtown                1545
# East Harlem            1117
# Chelsea                1113
# Lower East Side         911
# Washington Heights      899
# West Village            768
# Financial District      744
# Murray Hill             485
# Kips Bay                470
# Greenwich Village       392
# Chinatown               368
# SoHo                    358
# Morningside Heights     346
# Gramercy                338
# Theater District        288
# Nolita                  253
# Inwood                  252
# Tribeca                 177
# Little Italy            121
# Flatiron District        80
# NoHo                     78
# Roosevelt Island         77
# Two Bridges              72
# Battery Park City        70
# Civic Center             52
# Stuyvesant Town          37
# Marble Hill              12
# Name: neighbourhood, dtype: int64
# ...

# %%
man_b = df.loc[df['neighbourhood_group'] == 'Brooklyn']
print(man_b.neighbourhood.value_counts())

sns.countplot(y = man_b['neighbourhood'], palette = 'plasma')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Neighbourhood')

print(man_b.neighbourhood.nunique())
# Out:
# Williamsburg                 3920
# Bedford-Stuyvesant           3714
# Bushwick                     2465
# Crown Heights                1564
# Greenpoint                   1115
# Flatbush                      621
# Clinton Hill                  572
# Prospect-Lefferts Gardens     535
# Park Slope                    506
# East Flatbush                 500
# Fort Greene                   489
# Sunset Park                   390
# Prospect Heights              357
# South Slope                   284
# Gowanus                       247
# Carroll Gardens               233
# East New York                 218
# Boerum Hill                   177
# Kensington                    175
# Sheepshead Bay                164
# Windsor Terrace               157
# Brooklyn Heights              154
# Canarsie                      147
# Bay Ridge                     141
# Borough Park                  136
# Cypress Hills                 135
# Midwood                       109
# ...

# %%
man_b = df.loc[df['neighbourhood_group'] == 'Queens']
print(man_b.neighbourhood.value_counts())

sns.countplot(y = man_b['neighbourhood'], palette = 'plasma')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Neighbourhood')

print(man_b.neighbourhood.nunique())
# Out:
# Astoria                900
# Long Island City       537
# Flushing               426
# Ridgewood              423
# Sunnyside              363
# Ditmars Steinway       309
# Elmhurst               237
# Woodside               235
# Jamaica                231
# Jackson Heights        186
# East Elmhurst          185
# Forest Hills           144
# Maspeth                110
# Rego Park              106
# Richmond Hill           94
# Woodhaven               88
# Springfield Gardens     85
# Arverne                 77
# St. Albans              76
# Corona                  64
# Ozone Park              62
# Queens Village          60
# Rosedale                59
# Briarwood               56
# Rockaway Beach          56
# Glendale                54
# South Ozone Park        40
# Bayside                 39
# Kew Gardens             32
# Fresh Meadows           32
# Middle Village          31
# Far Rockaway            29
# Cambria Heights         26
# Kew Gardens Hills       26
# ...

# %%
man_b = df.loc[df['neighbourhood_group'] == 'Brooklyn']
print(man_b.neighbourhood.value_counts())

sns.countplot(y = man_b['neighbourhood'], palette = 'plasma')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Neighbourhood')

print(man_b.neighbourhood.nunique())
# Out:
# Williamsburg                 3920
# Bedford-Stuyvesant           3714
# Bushwick                     2465
# Crown Heights                1564
# Greenpoint                   1115
# Flatbush                      621
# Clinton Hill                  572
# Prospect-Lefferts Gardens     535
# Park Slope                    506
# East Flatbush                 500
# Fort Greene                   489
# Sunset Park                   390
# Prospect Heights              357
# South Slope                   284
# Gowanus                       247
# Carroll Gardens               233
# East New York                 218
# Boerum Hill                   177
# Kensington                    175
# Sheepshead Bay                164
# Windsor Terrace               157
# Brooklyn Heights              154
# Canarsie                      147
# Bay Ridge                     141
# Borough Park                  136
# Cypress Hills                 135
# Midwood                       109
# ...

# %%
man_b = df.loc[df['neighbourhood_group'] == 'Bronx']
print(man_b.neighbourhood.value_counts())

sns.countplot(y = man_b['neighbourhood'], palette = 'plasma')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Neighbourhood')

print(man_b.neighbourhood.nunique())
# Out:
# Kingsbridge           70
# Fordham               63
# Longwood              62
# Mott Haven            60
# Wakefield             50
# Concourse             50
# Port Morris           46
# Allerton              42
# Williamsbridge        40
# Parkchester           39
# Concourse Village     32
# Norwood               31
# Pelham Gardens        28
# Claremont Village     28
# Highbridge            27
# Belmont               24
# Throgs Neck           24
# University Heights    21
# Clason Point          21
# Mount Hope            20
# Bronxdale             19
# City Island           18
# Hunts Point           18
# Morrisania            18
# Pelham Bay            17
# Morris Heights        17
# Morris Park           15
# Soundview             15
# Eastchester           13
# Edenwald              13
# Schuylerville         13
# Fieldston             12
# Woodlawn              11
# Riverdale             11
# Van Nest              11
# Tremont               11
# North Riverdale       10
# ...

# %%
man_b = df.loc[df['neighbourhood_group'] == 'Staten Island']
print(man_b.neighbourhood.value_counts())

sns.countplot(y = man_b['neighbourhood'], palette = 'plasma')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Neighbourhood')

print(man_b.neighbourhood.nunique())
# Out:
# St. George                    48
# Tompkinsville                 42
# Stapleton                     27
# Concord                       26
# Arrochar                      21
# Randall Manor                 19
# West Brighton                 18
# Clifton                       15
# Great Kills                   10
# Port Richmond                  9
# Mariners Harbor                8
# New Springville                8
# South Beach                    8
# Shore Acres                    7
# Rosebank                       7
# Tottenville                    7
# Grymes Hill                    7
# Dongan Hills                   7
# Bull's Head                    6
# Grant City                     6
# Midland Beach                  6
# New Dorp Beach                 5
# Emerson Hill                   5
# Oakwood                        5
# New Brighton                   5
# Castleton Corners              4
# Todt Hill                      4
# Arden Heights                  4
# ...

# %% [markdown]
# ## Geospatial

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df.longitude,df.latitude,hue=df.neighbourhood_group)
plt.ioff()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df.longitude,df.latitude,hue=df.room_type)
plt.ioff()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df.longitude,df.latitude,hue=df.availability_365)
plt.ioff()

# %% [markdown]
# ## Regression Analysis

# %%
df.drop(['host_id','latitude','longitude','neighbourhood','number_of_reviews',
         'reviews_per_month', 'name','id','host_name','last_review'], axis=1, inplace=True)

df.head(5)

df.dropna(how='any',inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder   
le = LabelEncoder() 

df['neighbourhood_group'] = le.fit_transform(df['neighbourhood_group']) 
df['room_type'] = le.fit_transform(df['room_type']) 

df.head()
# Out:
#    neighbourhood_group  room_type  price  minimum_nights  \
# 0                    1          1    149               1
# 1                    2          0    225               1
# 2                    2          1    150               3
# 3                    1          0     89               1
# 4                    2          0     80              10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score

# %%
#Defining the independent variables and dependent variables
x = df.iloc[:,[0,1,3,4,5]]
y = df['price']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1,random_state=353)
x_train.head()
y_train.head()
# Out:
# 17736    125
# 24351    101
# 10069    189
# 11679    145
# 16315    120
# Name: price, dtype: int64

# %%
df.isnull().sum()

# %%
from sklearn.tree import DecisionTreeRegressor
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1,random_state=105)
DTree=DecisionTreeRegressor(min_samples_leaf=.0001)
DTree.fit(x_train,y_train)
y_predict=DTree.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_predict)
# Out:
# 0.24742965608385814
